# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("plant_genomes_master_list.csv")
df.head(20)
# Out:
#                 binomial_name            scientific_name      assembly_id  \
# 0          Brasenia schreberi         Brasenia schreberi  GCA_030142015.1
# 1        Bruguiera cylindrica       Bruguiera cylindrica  GCA_023213415.1
# 2        Bruguiera gymnorhiza       Bruguiera gymnorhiza  GCA_020883675.1
# 3        Bruguiera parviflora       Bruguiera parviflora  GCA_019804595.1
# 4         Bruguiera sexangula        Bruguiera sexangula  GCA_020141445.1
# 5       Buddleja alternifolia      Buddleja alternifolia  GCA_019426215.1
# 6           Bursera bipinnata          Bursera bipinnata  GCA_026225755.1
# 7             Bursera palmeri            Bursera palmeri  GCA_026225775.1
# 8          Buxus sempervirens         Buxus sempervirens  GCA_947561395.3
# 9        Callicarpa nudiflora       Callicarpa nudiflora  GCA_049355005.1
# 10      Calochortus purpureus      Calochortus purpureus  GCA_051254195.1
# 11         Calotropis procera         Calotropis procera  GCA_047371215.1
# ...

# %%
# df_genome = df[["scientific_name", "redlistCategory", "genome_size"]]
df["scientific_name"] = df["scientific_name"].str.lower()

# %%
df_genomes = df[["scientific_name", "redlistCategory", "genome_size"]]

# %%
df_genomes.to_csv("plant_genome.csv", index=False)
