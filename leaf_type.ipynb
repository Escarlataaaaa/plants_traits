# %%
import pandas as pd

# %%
df = pd.read_csv("47179.txt", sep='\t', encoding='latin-1')
df.head()
# Out:
# /var/folders/h6/qd2kpqfj4_35f63hmcw_m0nc0000gn/T/ipykernel_5573/1797136013.py:1: DtypeWarning: Columns (16,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("47179.txt", sep='\t', encoding='latin-1')
#       LastName FirstName  DatasetID                      Dataset  \
# 0  Cornelissen  Johannes          1  Abisko & Sheffield Database
# 1  Cornelissen  Johannes          1  Abisko & Sheffield Database
# 2  Cornelissen  Johannes          1  Abisko & Sheffield Database
# 3  Cornelissen  Johannes          1  Abisko & Sheffield Database
# 4  Cornelissen  Johannes          1  Abisko & Sheffield Database
#
#       SpeciesName  AccSpeciesID  AccSpeciesName  ObservationID  ObsDataID  \
# 0  Carex rostrata         10647  Carex rostrata         172602    1808373
# 1  Carex rostrata         10647  Carex rostrata         172602    1808374
# 2  Carex rostrata         10647  Carex rostrata         172602    1808375
# ...

# %%
df_trait_id = df[df['TraitID'].notna()]
df_trait_id.head()
# Out:
#        LastName FirstName  DatasetID                      Dataset  \
# 13  Cornelissen  Johannes          1  Abisko & Sheffield Database
# 34  Cornelissen  Johannes          1  Abisko & Sheffield Database
# 55  Cornelissen  Johannes          1  Abisko & Sheffield Database
# 76  Cornelissen  Johannes          1  Abisko & Sheffield Database
# 97  Cornelissen  Johannes          1  Abisko & Sheffield Database
#
#                  SpeciesName  AccSpeciesID            AccSpeciesName  \
# 13            Carex rostrata         10647            Carex rostrata
# 34  Eriophorum angustifolium         21805  Eriophorum angustifolium
# 55       Filipendula ulmaria         24995       Filipendula ulmaria
# 76            Carex rostrata         10647            Carex rostrata
# 97  Eriophorum angustifolium         21805  Eriophorum angustifolium
#
#     ObservationID  ObsDataID  TraitID  ... Replicates  StdValue UnitName  \
# 13         172602    1808387     43.0  ...        NaN       NaN      NaN
# ...

# %%
df_trait_id.nunique()
# Out:
# LastName                   20
# FirstName                  19
# DatasetID                  24
# Dataset                    22
# SpeciesName               377
# AccSpeciesID              253
# AccSpeciesName            253
# ObservationID            6420
# ObsDataID                6450
# TraitID                     1
# TraitName                   1
# DataID                      4
# DataName                    4
# OriglName                  20
# OrigValueStr               20
# OrigUnitStr                 0
# ValueKindName               1
# OrigUncertaintyStr          0
# UncertaintyName             0
# Replicates                  0
# StdValue                    0
# UnitName                    0
# RelUncertaintyPercent       0
# OrigObsDataID               0
# ErrorRisk                   0
# Reference                  21
# Comment                     9
# StdValueStr                 0
# Unnamed: 28                 0
# dtype: int64

# %%
cols = []
df_trait_id = df_trait_id.
